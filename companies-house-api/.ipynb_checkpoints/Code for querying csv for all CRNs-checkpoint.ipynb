# %% [markdown]
# # Code on filtering GPG data csv to retrieve all of CRNs to query Companies House API

# %%
import pandas as pd
import time
from query_companies_house import *

# %%
df = pd.read_csv("UK_Gender_Pay_Gap_Data_2017_to_2018.csv")

# %%
df.columns
# Out:
# Index(['EmployerName', 'Address', 'CompanyNumber', 'SicCodes',
#        'DiffMeanHourlyPercent', 'DiffMedianHourlyPercent',
#        'DiffMeanBonusPercent', 'DiffMedianBonusPercent', 'MaleBonusPercent',
#        'FemaleBonusPercent', 'MaleLowerQuartile', 'FemaleLowerQuartile',
#        'MaleLowerMiddleQuartile', 'FemaleLowerMiddleQuartile',
#        'MaleUpperMiddleQuartile', 'FemaleUpperMiddleQuartile',
#        'MaleTopQuartile', 'FemaleTopQuartile', 'CompanyLinkToGPGInfo',
#        'ResponsiblePerson', 'EmployerSize', 'CurrentName',
#        'SubmittedAfterTheDeadline'],
#       dtype='object')

# %%
df.CompanyNumber.values
# Out:
# array(['00226143', 'SC016876', '03951948', ..., '03843124', '08563366',
#        '01032611'], dtype=object)

# %%
len(df)
# Out:
# 10513

# %%
no_nans = df.dropna(subset=['CompanyNumber'])

# %%
len(no_nans)
# Out:
# 9167

# %%
company_numbers = no_nans.CompanyNumber.values

# %%
def chunk_maker(iterable, size):
    for i in range(0, len(iterable), size):
        yield iterable[i:i + size]

# %%
count = 0
for chunk in chunk_maker(company_numbers, 250):
    for company_num in chunk:
        format_active_officers_info(query_company_name, query_officers_info, company_num)
        count += 1
        print(count)
    time.sleep(300 * 2)
# Out:
# {
#     "Company_Name": "\"BRYANSTON SCHOOL\",INCORPORATED",
#     "Company_Registration_Number": "00226143",
#     "Names_Active_Officers": [
#         "MCGOVERN, Michael Aidan John",
#         "BICKFORD, Natalie",
#         "BOWES, Simon Foster",
#         "BROAD, Benedict Peter",
#         "CONRAN, Sebastian Orby",
#         "FLEMING, Katherine Maire-Anne, Dr",
#         "FORTESCUE, John Andrew Francis",
#         "FOULSER, Susan",
#         "GREENHILL, Julian Rutherford",
#         "HOLT, Lucinda Jane, The Revd",
#         "IRVANI, Bahman",
#         "LAURENCE, Mark Aubrey Seymour",
#         "MARTIN, Christopher George",
#         "MCDONAUGH, Victoria Mary",
#         "MCKEOWN, Mabel Ellen",
#         "PHARAOH, Hannah Mary, Dr",
#         "POULTON, Anthony Richard",
#         "SODEN, Louise Marcelle Victoria",
#         "TRICK, David Mark"
#     ],
#     "Number_Active_Officers": 19,
#     "Officers_Active_Full_Info": [
#         {
#             "address": {
#                 "address_line_1": "Bryanston House",
#                 "address_line_2": "Blandford",
#                 "locality": "Dorset",
#                 "postal_code": "DT11 0PX"
#             },
#             "appointed_on": "2018-04-16",
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/LX4cy6cYr24GNW6sbJQd5sK16dY/appointments"
#                 }
#             },
#             "name": "MCGOVERN, Michael Aidan John",
#             "officer_role": "secretary"
#         },
#         {
#             "address": {
#                 "address_line_1": "Bryanston House",
#                 "address_line_2": "Blandford",
#                 "locality": "Dorset",
#                 "postal_code": "DT11 0PX"
#             },
#             "appointed_on": "2017-03-04",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 7,
#                 "year": 1970
#             },
#             "former_names": [
#                 {
#                     "surname": "PROPPER"
#                 }
#             ],
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/8GK3qHK4ATvmCso5dDpRIYtYJ84/appointments"
#                 }
#             },
#             "name": "BICKFORD, Natalie",
#             "nationality": "British",
#             "occupation": "Human Resources Director",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Corner Cottage",
#                 "address_line_2": "Tarrant Keyneston",
#                 "locality": "Blandford Forum",
#                 "postal_code": "DT11 9JE",
#                 "region": "Dorset"
#             },
#             "appointed_on": "2004-05-22",
#             "country_of_residence": "United Kingdom",
#             "date_of_birth": {
#                 "month": 6,
#                 "year": 1951
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/T-NcdUKwi7ZD_RzcZY4XsJC41yA/appointments"
#                 }
#             },
#             "name": "BOWES, Simon Foster",
#             "nationality": "British",
#             "occupation": "Tea Merchant",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Bryanston House",
#                 "address_line_2": "Blandford",
#                 "locality": "Dorset",
#                 "postal_code": "DT11 0PX"
#             },
#             "appointed_on": "2017-03-04",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 11,
#                 "year": 1985
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/evlOa7c26wtMvDeR47kGmkKmcM0/appointments"
#                 }
#             },
#             "name": "BROAD, Benedict Peter",
#             "nationality": "British",
#             "occupation": "Director",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Bryanston House",
#                 "address_line_2": "Blandford",
#                 "locality": "Dorset",
#                 "postal_code": "DT11 0PX"
#             },
#             "appointed_on": "2011-11-19",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 4,
#                 "year": 1956
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/-WkEUFDJN64aReJHpdXeiGaS2sk/appointments"
#                 }
#             },
#             "name": "CONRAN, Sebastian Orby",
#             "nationality": "British",
#             "occupation": "Designer",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Bryanston House",
#                 "address_line_2": "Blandford",
#                 "locality": "Dorset",
#                 "postal_code": "DT11 0PX"
#             },
#             "appointed_on": "2015-03-07",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 8,
#                 "year": 1978
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/hjHd7GCYeKIbi5vkEoyC03-g_4o/appointments"
#                 }
#             },
#             "name": "FLEMING, Katherine Maire-Anne, Dr",
#             "nationality": "British",
#             "occupation": "Director Of Undergraduate Admissions For English",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Bryanston House",
#                 "address_line_2": "Blandford",
#                 "locality": "Dorset",
#                 "postal_code": "DT11 0PX"
#             },
#             "appointed_on": "2015-03-07",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 3,
#                 "year": 1955
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/_LqmcMjU2Z3Afb019S18OEmz344/appointments"
#                 }
#             },
#             "name": "FORTESCUE, John Andrew Francis",
#             "nationality": "British",
#             "occupation": "Executive Search Recruitment",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Barnwells Abbey Street",
#                 "address_line_2": "Cerne Abbas",
#                 "locality": "Dorchester",
#                 "postal_code": "DT2 7JQ",
#                 "region": "Dorset"
#             },
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 8,
#                 "year": 1949
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/ZVff1kMVn5sNsMV75bkInyxEMaI/appointments"
#                 }
#             },
#             "name": "FOULSER, Susan",
#             "nationality": "British",
#             "occupation": "Consultant",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Bryanston House",
#                 "address_line_2": "Blandford",
#                 "locality": "Dorset",
#                 "postal_code": "DT11 0PX"
#             },
#             "appointed_on": "1999-06-19",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 2,
#                 "year": 1973
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/g1Ijox3edLOFRMcGbXxcVE9Raoc/appointments"
#                 }
#             },
#             "name": "GREENHILL, Julian Rutherford",
#             "nationality": "British",
#             "occupation": "Barrister At Law",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Bryanston House",
#                 "address_line_2": "Blandford",
#                 "locality": "Dorset",
#                 "postal_code": "DT11 0PX"
#             },
#             "appointed_on": "2015-03-07",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 1,
#                 "year": 1965
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/I3WuuRQ-3A6r8zEmEQkEreN5NuM/appointments"
#                 }
#             },
#             "name": "HOLT, Lucinda Jane, The Revd",
#             "nationality": "British",
#             "occupation": "Clergy",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "1018 Benton Place",
#                 "country": "United States",
#                 "locality": "Atlanta",
#                 "region": "Georgia 30327"
#             },
#             "appointed_on": "2002-03-16",
#             "country_of_residence": "United States",
#             "date_of_birth": {
#                 "month": 2,
#                 "year": 1952
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/Gn5vZ9Pw3enCKtltsfi6JVSbxco/appointments"
#                 }
#             },
#             "name": "IRVANI, Bahman",
#             "nationality": "British",
#             "occupation": "Business",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Clockhouse Close",
#                 "country": "England",
#                 "locality": "London",
#                 "postal_code": "SW19 5NT",
#                 "premises": "1 Clockhouse Close"
#             },
#             "appointed_on": "2002-03-16",
#             "country_of_residence": "United Kingdom",
#             "date_of_birth": {
#                 "month": 7,
#                 "year": 1968
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/uLtEgsKQNe4rELMF3fxP8E0zTKk/appointments"
#                 }
#             },
#             "name": "LAURENCE, Mark Aubrey Seymour",
#             "nationality": "British",
#             "occupation": "Consultant",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Frog Lane",
#                 "address_line_2": "Motcombe",
#                 "country": "England",
#                 "locality": "Shaftesbury",
#                 "postal_code": "SP7 9NY",
#                 "premises": "Frog Lane Farm",
#                 "region": "Dorset"
#             },
#             "appointed_on": "2015-12-03",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 10,
#                 "year": 1957
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/zmpgpp0cnaMXzK_uGzg8RipDGmE/appointments"
#                 }
#             },
#             "name": "MARTIN, Christopher George",
#             "nationality": "British",
#             "occupation": "Retired",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Bryanston House",
#                 "address_line_2": "Blandford",
#                 "locality": "Dorset",
#                 "postal_code": "DT11 0PX"
#             },
#             "appointed_on": "2000-06-17",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 12,
#                 "year": 1950
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/GsrXVLwgn3sPSPuGNmVWqh-bsnU/appointments"
#                 }
#             },
#             "name": "MCDONAUGH, Victoria Mary",
#             "nationality": "British",
#             "occupation": "Teacher",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Bryanston House",
#                 "address_line_2": "Blandford",
#                 "locality": "Dorset",
#                 "postal_code": "DT11 0PX"
#             },
#             "appointed_on": "2015-03-07",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 4,
#                 "year": 1986
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/hoE39Ak97jCC0QvFejaVEnqrANc/appointments"
#                 }
#             },
#             "name": "MCKEOWN, Mabel Ellen",
#             "nationality": "British",
#             "occupation": "Charity Fundraiser",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Sherwood Avenue",
#                 "country": "United Kingdom",
#                 "locality": "Poole",
#                 "postal_code": "BH14 8DH",
#                 "premises": "35",
#                 "region": "Dorset"
#             },
#             "appointed_on": "2006-03-11",
#             "country_of_residence": "United Kingdom",
#             "date_of_birth": {
#                 "month": 2,
#                 "year": 1976
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/r_PQ-9wdwLkd7HYAG1CGoT1pA8A/appointments"
#                 }
#             },
#             "name": "PHARAOH, Hannah Mary, Dr",
#             "nationality": "British",
#             "occupation": "Doctor",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "West Chiltington Lane",
#                 "locality": "Billingshurst",
#                 "postal_code": "RH14 9DP",
#                 "premises": "Pear Tree Farm",
#                 "region": "West Sussex"
#             },
#             "appointed_on": "2007-03-03",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 2,
#                 "year": 1969
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/swCmEfV483gR3wH3Ku-f9lgdu78/appointments"
#                 }
#             },
#             "name": "POULTON, Anthony Richard",
#             "nationality": "British",
#             "occupation": "Solicitor",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Bryanston House",
#                 "address_line_2": "Blandford",
#                 "locality": "Dorset",
#                 "postal_code": "DT11 0PX"
#             },
#             "appointed_on": "2015-03-07",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 5,
#                 "year": 1952
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/i29pypqzTWsbrGLERS2Lrk8wicg/appointments"
#                 }
#             },
#             "name": "SODEN, Louise Marcelle Victoria",
#             "nationality": "British",
#             "occupation": "Education",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Bryanston House",
#                 "address_line_2": "Blandford",
#                 "locality": "Dorset",
#                 "postal_code": "DT11 0PX"
#             },
#             "appointed_on": "2011-03-12",
#             "country_of_residence": "United Kingdom",
#             "date_of_birth": {
#                 "month": 10,
#                 "year": 1960
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/aRsJkZvJL6rzurjiqiY0Zr0BEoM/appointments"
#                 }
#             },
#             "name": "TRICK, David Mark",
#             "nationality": "British",
#             "occupation": "Director",
#             "officer_role": "director"
#         }
#     ]
# }
# 1
# {
#     "Company_Name": "\"RED BAND\" CHEMICAL COMPANY, LIMITED",
#     "Company_Registration_Number": "SC016876",
#     "Names_Active_Officers": [
#         "VALENTINE, Dianne Davidson",
#         "CLUBB, Malcolm Richard",
#         "CUMMING, Alexander Coulson",
#         "CUMMING, Charles Nigel Coulson",
#         "GALT, Philip Callaghan",
#         "ROBERTS, Angus"
#     ],
#     "Number_Active_Officers": 6,
#     "Officers_Active_Full_Info": [
#         {
#             "address": {
#                 "address_line_1": "19 Smith's Place",
#                 "address_line_2": "Leith Walk",
#                 "locality": "Edinburgh",
#                 "postal_code": "EH6 8NU"
#             },
#             "appointed_on": "2015-05-11",
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/GFjMNO2xozU4sGApm6NPhQCguJo/appointments"
#                 }
#             },
#             "name": "VALENTINE, Dianne Davidson",
#             "officer_role": "secretary"
#         },
#         {
#             "address": {
#                 "address_line_1": "19 Smith's Place",
#                 "address_line_2": "Leith Walk",
#                 "locality": "Edinburgh",
#                 "postal_code": "EH6 8NU"
#             },
#             "appointed_on": "2018-05-09",
#             "country_of_residence": "Scotland",
#             "date_of_birth": {
#                 "month": 2,
#                 "year": 1974
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/rDvZSHZWCEO9NTX4lSEVIb4eiHs/appointments"
#                 }
#             },
#             "name": "CLUBB, Malcolm Richard",
#             "nationality": "British",
#             "occupation": "Director / Deputy Superintendent Pharmacist",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Abernyte",
#                 "locality": "Perth",
#                 "postal_code": "PH14 9ST",
#                 "premises": "Lappin Cottage"
#             },
#             "country_of_residence": "Scotland",
#             "date_of_birth": {
#                 "month": 2,
#                 "year": 1948
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/xiTfJhdGP_SnvYhVH9Qbu9W-jek/appointments"
#                 }
#             },
#             "name": "CUMMING, Alexander Coulson",
#             "nationality": "British",
#             "occupation": "Company Director",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "9 Minto Street",
#                 "locality": "Edinburgh",
#                 "postal_code": "EH9 1RG",
#                 "region": "Midlothian"
#             },
#             "country_of_residence": "Scotland",
#             "date_of_birth": {
#                 "month": 12,
#                 "year": 1952
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/CfJWsRtnKtdfWJxltn3sR_iHswk/appointments"
#                 }
#             },
#             "name": "CUMMING, Charles Nigel Coulson",
#             "nationality": "British",
#             "occupation": "Chief Executive",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "19 Smith's Place",
#                 "address_line_2": "Leith Walk",
#                 "locality": "Edinburgh",
#                 "postal_code": "EH6 8NU"
#             },
#             "appointed_on": "2014-08-19",
#             "country_of_residence": "Scotland",
#             "date_of_birth": {
#                 "month": 2,
#                 "year": 1970
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/SuJtaUQCm1mtH8Yscg1tWhFCdyw/appointments"
#                 }
#             },
#             "name": "GALT, Philip Callaghan",
#             "nationality": "British",
#             "occupation": "Managing Director/Superintendant Pharmacist",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Smith's Place",
#                 "country": "Scotland",
#                 "locality": "Edinburgh",
#                 "postal_code": "EH6 8NU",
#                 "premises": "19"
#             },
#             "appointed_on": "2012-02-24",
#             "country_of_residence": "Scotland",
#             "date_of_birth": {
#                 "month": 6,
#                 "year": 1979
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/CXKyqrYzWGDpfGX0TA8bNd2-EL8/appointments"
#                 }
#             },
#             "name": "ROBERTS, Angus",
#             "nationality": "British",
#             "occupation": "Pharmacy Manager",
#             "officer_role": "director"
#         }
#     ]
# }
# 2
# {
#     "Company_Name": "118 LIMITED",
#     "Company_Registration_Number": "03951948",
#     "Names_Active_Officers": [
#         "RIEGER, Derek",
#         "GRAHAM, Michael",
#         "RAVAL, Pradipkumar",
#         "RIEGER, Derek"
#     ],
#     "Number_Active_Officers": 4,
#     "Officers_Active_Full_Info": [
#         {
#             "address": {
#                 "address_line_1": "Dumballs Road",
#                 "locality": "Cardiff",
#                 "postal_code": "CF10 5BF",
#                 "premises": "Fusion Point"
#             },
#             "appointed_on": "2016-01-26",
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/E_XzaLeLmYlGaeKjkeYXN1zY0E0/appointments"
#                 }
#             },
#             "name": "RIEGER, Derek",
#             "officer_role": "secretary"
#         },
#         {
#             "address": {
#                 "address_line_1": "Dumballs Road",
#                 "locality": "Cardiff",
#                 "postal_code": "CF10 5BF",
#                 "premises": "Fusion Point"
#             },
#             "appointed_on": "2016-06-10",
#             "country_of_residence": "United States",
#             "date_of_birth": {
#                 "month": 12,
#                 "year": 1980
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/UFoglknmBoK-OlLN01d6t6qbynw/appointments"
#                 }
#             },
#             "name": "GRAHAM, Michael",
#             "nationality": "American",
#             "occupation": "Director",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Dumballs Road",
#                 "locality": "Cardiff",
#                 "postal_code": "CF10 5BF",
#                 "premises": "Fusion Point"
#             },
#             "appointed_on": "2014-05-30",
#             "country_of_residence": "United States",
#             "date_of_birth": {
#                 "month": 11,
#                 "year": 1957
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/NN3A4XJXfEEfIyvKvA4llc-kxGg/appointments"
#                 }
#             },
#             "name": "RAVAL, Pradipkumar",
#             "nationality": "American",
#             "occupation": "Chief Financial Officer",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Dumballs Road",
#                 "locality": "Cardiff",
#                 "postal_code": "CF10 5BF",
#                 "premises": "Fusion Point"
#             },
#             "appointed_on": "2016-01-27",
#             "country_of_residence": "United States",
#             "date_of_birth": {
#                 "month": 9,
#                 "year": 1980
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/z_9WkAmr93_bx0RF8Y5FLlpBsTo/appointments"
#                 }
#             },
#             "name": "RIEGER, Derek",
#             "nationality": "American",
#             "occupation": "Attorney",
#             "officer_role": "director"
#         }
#     ]
# }
# 3
# {
#     "Company_Name": "123 EMPLOYEES LTD",
#     "Company_Registration_Number": "10530651",
#     "Names_Active_Officers": [
#         "BUCK, Stephen Andrew"
#     ],
#     "Number_Active_Officers": 1,
#     "Officers_Active_Full_Info": [
#         {
#             "address": {
#                 "address_line_1": "Education Road",
#                 "country": "United Kingdom",
#                 "locality": "Leeds",
#                 "postal_code": "LS7 2AL",
#                 "premises": "Alexandra House"
#             },
#             "appointed_on": "2016-12-17",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 5,
#                 "year": 1958
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/e3wm-8jK6SZxvbt5eVDs-d7AxdI/appointments"
#                 }
#             },
#             "name": "BUCK, Stephen Andrew",
#             "nationality": "British",
#             "occupation": "Business Owner",
#             "officer_role": "director"
#         }
#     ]
# }
# 4
# {
#     "Company_Name": "1610 LIMITED",
#     "Company_Registration_Number": "06727055",
#     "Names_Active_Officers": [
#         "FOX, Peter Richard",
#         "BEVINS, Rebecca Elizabeth",
#         "SLADDEN, Jonathan Michael, Dr",
#         "WINLOW, Malcolm"
#     ],
#     "Number_Active_Officers": 4,
#     "Officers_Active_Full_Info": [
#         {
#             "address": {
#                 "address_line_1": "Honiton Road",
#                 "address_line_2": "Trull",
#                 "country": "England",
#                 "locality": "Taunton",
#                 "postal_code": "TA3 7JW",
#                 "premises": "Highbank",
#                 "region": "Somerset"
#             },
#             "appointed_on": "2016-08-09",
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/J3o1FTUYP5828Hj2uo9SDC3MXJY/appointments"
#                 }
#             },
#             "name": "FOX, Peter Richard",
#             "officer_role": "secretary"
#         },
#         {
#             "address": {
#                 "address_line_1": "Cheddon Fitzpaine",
#                 "locality": "Taunton",
#                 "postal_code": "TA2 8LG",
#                 "premises": "Hestercombe House",
#                 "region": "Somerset"
#             },
#             "appointed_on": "2013-07-04",
#             "country_of_residence": "United Kingdom",
#             "date_of_birth": {
#                 "month": 10,
#                 "year": 1970
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/oSus2T3mjpRMmHuV91Cx_jBrRm8/appointments"
#                 }
#             },
#             "name": "BEVINS, Rebecca Elizabeth",
#             "nationality": "British",
#             "occupation": "Consultant",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "6 Stone Close",
#                 "locality": "Taunton",
#                 "postal_code": "TA1 4YG",
#                 "region": "Somerset"
#             },
#             "appointed_on": "2009-06-29",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 3,
#                 "year": 1953
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/Yw11sA4CK84JL9py1ni9EhAWTDc/appointments"
#                 }
#             },
#             "name": "SLADDEN, Jonathan Michael, Dr",
#             "nationality": "British",
#             "occupation": "Gp",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Greystone House 4 Saxon Way",
#                 "locality": "Wedmore",
#                 "postal_code": "BS28 4AG",
#                 "region": "Somerset"
#             },
#             "appointed_on": "2009-06-29",
#             "country_of_residence": "United Kingdom",
#             "date_of_birth": {
#                 "month": 6,
#                 "year": 1943
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/_gkM8nUMQ3km9GiJyW82AAvsAoI/appointments"
#                 }
#             },
#             "name": "WINLOW, Malcolm",
#             "nationality": "British",
#             "occupation": "Retired",
#             "officer_role": "director"
#         }
#     ]
# }
# 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-929d1a11e760> in <module>()
#       2 for chunk in chunk_maker(company_numbers, 250):
#       3     for company_num in chunk:
# ----> 4         format_active_officers_info(query_company_name, query_officers_info, company_num)
#       5         count += 1
#       6         print(count)
#
# ~/Documents/paygaphack/companies-house-api/query_companies_house.py in format_active_officers_info(query_comp_name, query_off_info, company_num)
#      86     """
#      87     company_name = query_comp_name(company_num)
# ---> 88     officers_data = query_off_info(company_num)
#      89     if officers_data != 'CRN not listed with Companies House':
#      90         num_active = int(officers_data["active_count"])
#
# ~/Documents/paygaphack/companies-house-api/query_companies_house.py in query_officers_info(company_num)
#      62     OUTPUT: all officers' information for that company: JSON
#      63     """
# ---> 64     response = requests.get(BASE_URL + company_num + '/officers', auth=(API_KEY, ''))
#      65     # print("\nRetrieving officers' info for company:{} ...".format(company_num))
#      66
#
# ~/anaconda3/envs/companies-house-api/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/envs/companies-house-api/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/envs/companies-house-api/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# ~/anaconda3/envs/companies-house-api/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/companies-house-api/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     443                     decode_content=False,
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#     447
#
# ~/anaconda3/envs/companies-house-api/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/envs/companies-house-api/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/envs/companies-house-api/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     847         # Force connect early to allow us to validate the connection.
#     848         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 849             conn.connect()
#     850
#     851         if not conn.is_verified:
#
# ~/anaconda3/envs/companies-house-api/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     312     def connect(self):
#     313         # Add certificate verification
# --> 314         conn = self._new_conn()
#     315
#     316         hostname = self.host
#
# ~/anaconda3/envs/companies-house-api/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     169         try:
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#     173         except SocketTimeout as e:
#
# ~/anaconda3/envs/companies-house-api/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      54     family = allowed_gai_family()
#      55
# ---> 56     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      57         af, socktype, proto, canonname, sa = res
#      58         sock = None
#
# ~/anaconda3/envs/companies-house-api/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     743     # and socket type values to enum constants.
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#     747         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:
