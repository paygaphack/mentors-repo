# %% [markdown]
# # Demo Code on how to filter GPG data csv to retrieve set of CRNs to query Companies House API

# %%
import pandas as pd
from query_companies_house import *

# %%
df = pd.read_csv("UK_Gender_Pay_Gap_Data_2017_to_2018.csv")

# %%
df.columns
# Out:
# Index(['EmployerName', 'Address', 'CompanyNumber', 'SicCodes',
#        'DiffMeanHourlyPercent', 'DiffMedianHourlyPercent',
#        'DiffMeanBonusPercent', 'DiffMedianBonusPercent', 'MaleBonusPercent',
#        'FemaleBonusPercent', 'MaleLowerQuartile', 'FemaleLowerQuartile',
#        'MaleLowerMiddleQuartile', 'FemaleLowerMiddleQuartile',
#        'MaleUpperMiddleQuartile', 'FemaleUpperMiddleQuartile',
#        'MaleTopQuartile', 'FemaleTopQuartile', 'CompanyLinkToGPGInfo',
#        'ResponsiblePerson', 'EmployerSize', 'CurrentName',
#        'SubmittedAfterTheDeadline'],
#       dtype='object')

# %%
df.EmployerSize.unique()
# Out:
# array(['500 to 999', '250 to 499', '5000 to 19,999', '1000 to 4999',
#        'Not Provided', 'Less than 250', '20,000 or more'], dtype=object)

# %%
df = df[(df.EmployerSize != '250 to 499') & (df.EmployerSize != 'Less than 250') & (df.EmployerSize != 'Not Provided')]

# %%
df.loc[0]
# Out:
# EmployerName                                   "Bryanston School",Incorporated
# Address                      Bryanston House,\r\nBlandford,\r\nDorset,\r\nU...
# CompanyNumber                                                         00226143
# SicCodes                                                                 85310
# DiffMeanHourlyPercent                                                       18
# DiffMedianHourlyPercent                                                   28.2
# DiffMeanBonusPercent                                                         0
# DiffMedianBonusPercent                                                       0
# MaleBonusPercent                                                             0
# FemaleBonusPercent                                                           0
# MaleLowerQuartile                                                         24.4
# FemaleLowerQuartile                                                       75.6
# MaleLowerMiddleQuartile                                                   50.8
# FemaleLowerMiddleQuartile                                                 49.2
# MaleUpperMiddleQuartile                                                   49.2
# FemaleUpperMiddleQuartile                                                 50.8
# MaleTopQuartile                                                           51.5
# FemaleTopQuartile                                                         48.5
# CompanyLinkToGPGInfo                    https://www.bryanston.co.uk/employment
# ResponsiblePerson              Nick McRobb (Bursar and Clerk to the Governors)
# EmployerSize                                                        500 to 999
# CurrentName                                    "Bryanston School",Incorporated
# SubmittedAfterTheDeadline                                                False
# Name: 0, dtype: object

# %%
df.head()
# Out:
#                           EmployerName  \
# 0      "Bryanston School",Incorporated
# 2                          118 LIMITED
# 6   1LIFE MANAGEMENT SOLUTIONS LIMITED
# 10        2 SISTERS FOOD GROUP LIMITED
# 11           2 SISTERS POULTRY LIMITED
#
#                                               Address CompanyNumber  \
# 0   Bryanston House,\r\nBlandford,\r\nDorset,\r\nU...      00226143
# 2   Fusion Point,\r\nDumballs Road,\r\nCardiff,\r\...      03951948
# 6   Ldh House St Ives Business Park,\r\nParsons Gr...      02566586
# 10  Trinity Park House Trinity Business Park, Fox ...      02826929
# 11  George Street, Coupar Angus,\r\nBlairgowrie,\r...      SC440782
#
#                      SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 0                       85310                   18.0                     28.2
# 2                       61900                    1.7                      2.8
# 6   93110,\r\n93130,\r\n93290                   15.1                      2.8
# 10                      10120                   15.3                      6.9
# 11                      10120                    4.9                      4.8
#
#     DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 0                    0.0                     0.0               0.0
# 2                   13.1                    13.6              70.0
# 6                   77.6                    71.2               5.8
# 10                  55.5                     1.6               5.6
# 11                  39.8                     0.0              22.2
#
#     FemaleBonusPercent            ...             FemaleLowerMiddleQuartile  \
# 0                  0.0            ...                                  49.2
# 2                 57.0            ...                                  47.0
# 6                  4.2            ...                                  54.8
# 10                 5.1            ...                                  32.4
# 11                12.4            ...                                  31.5
#
#     MaleUpperMiddleQuartile  FemaleUpperMiddleQuartile  MaleTopQuartile  \
# 0                      49.2                       50.8             51.5
# 2                      50.0                       50.0             58.0
# 6                      46.8                       53.2             35.5
# 10                     66.2                       33.8             73.7
# 11                     68.5                       31.5             72.4
#
#     FemaleTopQuartile                               CompanyLinkToGPGInfo  \
# 0                48.5             https://www.bryanston.co.uk/employment
# 2                42.0                                                NaN
# 6                64.5              http://www.1life.co.uk/gender-pay-gap
# 10               26.3  https://www.2sfg.com/about-us/how-we-work/gender/
# 11               27.6  https://www.2sfg.com/about-us/how-we-work/gender/
#
#                                   ResponsiblePerson    EmployerSize  \
# 0   Nick McRobb (Bursar and Clerk to the Governors)      500 to 999
# 2                  Emma Crowe (VP, Human Resources)      500 to 999
# 6              Mark Braithwaite (Managing Director)      500 to 999
# 10     Nigel Perry (Group People & Change Director)  5000 to 19,999
# 11     Nigel Perry (Group People & Change Director)    1000 to 4999
#
#                            CurrentName SubmittedAfterTheDeadline
# 0      "Bryanston School",Incorporated                     False
# 2                          118 LIMITED                     False
# 6   1LIFE MANAGEMENT SOLUTIONS LIMITED                     False
# 10        2 SISTERS FOOD GROUP LIMITED                     False
# 11           2 SISTERS POULTRY LIMITED                     False
#
# [5 rows x 23 columns]

# %%
df_close_to_parity = df[(df['DiffMedianHourlyPercent'] < 5) & (df['DiffMedianHourlyPercent'] > 0)]

# %%
df_close_to_parity = df_close_to_parity.dropna(subset = ['CompanyNumber'])

# %%
company_numbers = df_close_to_parity.CompanyNumber.values

# %%
count = 0
for company_num in company_numbers:
    if count < 5:
        format_active_officers_info(query_company_name, query_officers_info, company_num)
        count += 1
    else:
        break
# Out:
# {
#     "Company_Name": "118 LIMITED",
#     "Company_Registration_Number": "03951948",
#     "Names_Active_Officers": [
#         "RIEGER, Derek",
#         "GRAHAM, Michael",
#         "RAVAL, Pradipkumar",
#         "RIEGER, Derek"
#     ],
#     "Number_Active_Officers": 4,
#     "Officers_Active_Full_Info": [
#         {
#             "address": {
#                 "address_line_1": "Dumballs Road",
#                 "locality": "Cardiff",
#                 "postal_code": "CF10 5BF",
#                 "premises": "Fusion Point"
#             },
#             "appointed_on": "2016-01-26",
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/E_XzaLeLmYlGaeKjkeYXN1zY0E0/appointments"
#                 }
#             },
#             "name": "RIEGER, Derek",
#             "officer_role": "secretary"
#         },
#         {
#             "address": {
#                 "address_line_1": "Dumballs Road",
#                 "locality": "Cardiff",
#                 "postal_code": "CF10 5BF",
#                 "premises": "Fusion Point"
#             },
#             "appointed_on": "2016-06-10",
#             "country_of_residence": "United States",
#             "date_of_birth": {
#                 "month": 12,
#                 "year": 1980
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/UFoglknmBoK-OlLN01d6t6qbynw/appointments"
#                 }
#             },
#             "name": "GRAHAM, Michael",
#             "nationality": "American",
#             "occupation": "Director",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Dumballs Road",
#                 "locality": "Cardiff",
#                 "postal_code": "CF10 5BF",
#                 "premises": "Fusion Point"
#             },
#             "appointed_on": "2014-05-30",
#             "country_of_residence": "United States",
#             "date_of_birth": {
#                 "month": 11,
#                 "year": 1957
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/NN3A4XJXfEEfIyvKvA4llc-kxGg/appointments"
#                 }
#             },
#             "name": "RAVAL, Pradipkumar",
#             "nationality": "American",
#             "occupation": "Chief Financial Officer",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Dumballs Road",
#                 "locality": "Cardiff",
#                 "postal_code": "CF10 5BF",
#                 "premises": "Fusion Point"
#             },
#             "appointed_on": "2016-01-27",
#             "country_of_residence": "United States",
#             "date_of_birth": {
#                 "month": 9,
#                 "year": 1980
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/z_9WkAmr93_bx0RF8Y5FLlpBsTo/appointments"
#                 }
#             },
#             "name": "RIEGER, Derek",
#             "nationality": "American",
#             "occupation": "Attorney",
#             "officer_role": "director"
#         }
#     ]
# }
#
# Saving active officers' information...
# {
#     "Company_Name": "1LIFE MANAGEMENT SOLUTIONS LIMITED",
#     "Company_Registration_Number": "02566586",
#     "Names_Active_Officers": [
#         "HENDRIE, Ian Arthur",
#         "BRAITHWAITE, Mark",
#         "HAMILL, Keith",
#         "HENDRIE, Ian Arthur",
#         "NICHOLLS, Julian Frederick"
#     ],
#     "Number_Active_Officers": 5,
#     "Officers_Active_Full_Info": [
#         {
#             "address": {
#                 "address_line_1": "St Ives Business Park",
#                 "address_line_2": "Parsons Green",
#                 "country": "England",
#                 "locality": "St. Ives",
#                 "postal_code": "PE27 4AA",
#                 "premises": "Ldh House",
#                 "region": "Cambridgeshire"
#             },
#             "appointed_on": "2014-04-04",
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/cToWQBUWQIMlwcOmWhz6QVTrCUE/appointments"
#                 }
#             },
#             "name": "HENDRIE, Ian Arthur",
#             "officer_role": "secretary"
#         },
#         {
#             "address": {
#                 "address_line_1": "St Ives Business Park",
#                 "address_line_2": "Parsons Green",
#                 "locality": "St. Ives",
#                 "postal_code": "PE27 4AA",
#                 "premises": "Ldh House",
#                 "region": "Cambridgeshire"
#             },
#             "appointed_on": "2018-02-01",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 1,
#                 "year": 1978
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/U6-0dI70re6c0z80YXHRFFAODWE/appointments"
#                 }
#             },
#             "name": "BRAITHWAITE, Mark",
#             "nationality": "British,South African",
#             "occupation": "Managing Director",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "St Ives Business Park",
#                 "address_line_2": "Parsons Green",
#                 "country": "England",
#                 "locality": "St. Ives",
#                 "postal_code": "PE27 4AA",
#                 "premises": "Ldh House",
#                 "region": "Cambridgeshire"
#             },
#             "appointed_on": "2012-07-16",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 12,
#                 "year": 1952
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/G6I3lR5qAob20kGZ75rjCgn3J08/appointments"
#                 }
#             },
#             "name": "HAMILL, Keith",
#             "nationality": "British",
#             "occupation": "Vice Chairman",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "St Ives Business Park",
#                 "address_line_2": "Parsons Green",
#                 "country": "England",
#                 "locality": "St. Ives",
#                 "postal_code": "PE27 4AA",
#                 "premises": "Ldh House",
#                 "region": "Cambridgeshire"
#             },
#             "appointed_on": "2014-03-04",
#             "country_of_residence": "United Kingdom",
#             "date_of_birth": {
#                 "month": 6,
#                 "year": 1970
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/trrY82yVl2mbM_jikpJ87vkAZu8/appointments"
#                 }
#             },
#             "name": "HENDRIE, Ian Arthur",
#             "nationality": "British",
#             "occupation": "Company Director",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Low Lane",
#                 "address_line_2": "Horsforth",
#                 "care_of": "DANOPTRA LIMITED",
#                 "locality": "Leeds",
#                 "postal_code": "LS18 4ER",
#                 "region": "West Yorkshire"
#             },
#             "appointed_on": "2011-03-18",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 9,
#                 "year": 1951
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/EiZ-AxHs1mO6V9jWSJR81Qi0_tU/appointments"
#                 }
#             },
#             "name": "NICHOLLS, Julian Frederick",
#             "nationality": "British",
#             "occupation": "None",
#             "officer_role": "director"
#         }
#     ]
# }
#
# Saving active officers' information...
# {
#     "Company_Name": "2 SISTERS POULTRY LIMITED",
#     "Company_Registration_Number": "SC440782",
#     "Names_Active_Officers": [
#         "BOPARAN, Ranjit Singh",
#         "FLETCHER, Martyn Paul",
#         "PACKER, Keith Richard",
#         "PIKE, Richard Neil"
#     ],
#     "Number_Active_Officers": 4,
#     "Officers_Active_Full_Info": [
#         {
#             "address": {
#                 "address_line_1": "Trinity Business Park",
#                 "address_line_2": "Fox Way",
#                 "country": "England",
#                 "locality": "Wakefield",
#                 "postal_code": "WF2 8EE",
#                 "premises": "Trinity Park House",
#                 "region": "West Yorkshire"
#             },
#             "appointed_on": "2013-03-08",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 8,
#                 "year": 1966
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/0-2xWafG0Zl52H0hY8m9QcD6OIk/appointments"
#                 }
#             },
#             "name": "BOPARAN, Ranjit Singh",
#             "nationality": "British",
#             "occupation": "Director",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Trinity Business Park",
#                 "country": "England",
#                 "locality": "Wakefield",
#                 "postal_code": "WF2 8EE",
#                 "premises": "Trinity Park House"
#             },
#             "appointed_on": "2017-07-17",
#             "country_of_residence": "United Kingdom",
#             "date_of_birth": {
#                 "month": 4,
#                 "year": 1967
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/Ph1I4_WOhXjgbVMgpQ4sKAgaEsE/appointments"
#                 }
#             },
#             "name": "FLETCHER, Martyn Paul",
#             "nationality": "British",
#             "occupation": "Coo",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Trinity Business Park",
#                 "country": "England",
#                 "locality": "Wakefield",
#                 "postal_code": "WF2 8EE",
#                 "premises": "Trinity Park House"
#             },
#             "appointed_on": "2018-04-04",
#             "country_of_residence": "Ireland",
#             "date_of_birth": {
#                 "month": 11,
#                 "year": 1967
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/qsIWNmGtMO0r4S5vqGyleFrVPOU/appointments"
#                 }
#             },
#             "name": "PACKER, Keith Richard",
#             "nationality": "British",
#             "occupation": "Managing Director",
#             "officer_role": "director"
#         },
#         {
#             "address": {
#                 "address_line_1": "Trinity Business Park",
#                 "country": "England",
#                 "locality": "Wakefield",
#                 "postal_code": "WF2 8EE",
#                 "premises": "Trinity Park House"
#             },
#             "appointed_on": "2017-08-22",
#             "country_of_residence": "United Kingdom",
#             "date_of_birth": {
#                 "month": 9,
#                 "year": 1969
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/GClacwu4hThgTpN9y0P3wPTVuPA/appointments"
#                 }
#             },
#             "name": "PIKE, Richard Neil",
#             "nationality": "British",
#             "occupation": "Group Cfo",
#             "officer_role": "director"
#         }
#     ]
# }
#
# Saving active officers' information...
# {
#     "Company_Name": "A & L RESTAURANTS LIMITED",
#     "Company_Registration_Number": "04437266",
#     "Names_Active_Officers": [
#         "ATEFI, Sophia Pari",
#         "ATEFI, Amir Hossein"
#     ],
#     "Number_Active_Officers": 2,
#     "Officers_Active_Full_Info": [
#         {
#             "address": {
#                 "address_line_1": "High Road",
#                 "address_line_2": "North Finchley",
#                 "care_of": "THE ACCOUNTING CENTRE, FIRST FLOOR",
#                 "country": "England",
#                 "locality": "London",
#                 "postal_code": "N12 9QD",
#                 "premises": "736"
#             },
#             "appointed_on": "2005-10-10",
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/fFGsuEo3qynz8MsaeiQxFhmXuJ4/appointments"
#                 }
#             },
#             "name": "ATEFI, Sophia Pari",
#             "nationality": "British",
#             "officer_role": "secretary"
#         },
#         {
#             "address": {
#                 "address_line_1": "High Road",
#                 "address_line_2": "North Finchley",
#                 "care_of": "THE ACCOUNTING CENTRE, FIRST FLOOR",
#                 "country": "England",
#                 "locality": "London",
#                 "postal_code": "N12 9QD",
#                 "premises": "736"
#             },
#             "appointed_on": "2002-05-16",
#             "country_of_residence": "United Kingdom",
#             "date_of_birth": {
#                 "month": 7,
#                 "year": 1961
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/j2kmyll7AvzjeaMxWSYH3WkbeME/appointments"
#                 }
#             },
#             "name": "ATEFI, Amir Hossein",
#             "nationality": "British",
#             "occupation": "Businessman",
#             "officer_role": "director"
#         }
#     ]
# }
#
# Saving active officers' information...
# {
#     "Company_Name": "A F A RESTAURANTS LIMITED",
#     "Company_Registration_Number": "08345484",
#     "Names_Active_Officers": [
#         "MUSTAFA, Ahmet"
#     ],
#     "Number_Active_Officers": 1,
#     "Officers_Active_Full_Info": [
#         {
#             "address": {
#                 "address_line_1": "High Road",
#                 "address_line_2": "North Finchley",
#                 "care_of": "THE ACCOUNTING CENTRE, FIRST FLOOR",
#                 "country": "England",
#                 "locality": "London",
#                 "postal_code": "N12 9QD",
#                 "premises": "736"
#             },
#             "appointed_on": "2013-01-03",
#             "country_of_residence": "England",
#             "date_of_birth": {
#                 "month": 12,
#                 "year": 1969
#             },
#             "links": {
#                 "officer": {
#                     "appointments": "/officers/zTo1LRKH03OGZu4QJgh4-GoHz4A/appointments"
#                 }
#             },
#             "name": "MUSTAFA, Ahmet",
#             "nationality": "British",
#             "occupation": "Director",
#             "officer_role": "director"
#         }
#     ]
# }
#
# Saving active officers' information...
